# %% [markdown]
# # Data Pre-processing, Exploratory Analysis and Data Prediction using Machine Learning

# %% [markdown]
# ## Description
#
# - #### Part A
#   - Apply data pre-processing techniques to a problem and do exploratory analysis on the dataset.
#
# - #### Part B
#   - Apply machine learning techniques and learn to perform machine learning with the Keras Python library.
#
# <br/><br/>

# %% [markdown]
# ### Required Libraries
# <ol>
#     <li>Numpy - Numerical python</li>
#     <li>Scipy - Scientific python</li>
#     <li>Matplotlib - Python 2D plotting library</li>
#     <li>Seaborn - Visualization library based on matplotlib</li>
#     <li>Pandas - Python data analysis library</li>
#     <li>Keras - Deep learning library</li>
# </ol>

# %% [markdown]
# ### Dataset ~ Titanic (titanic-train.csv)
# This dataset contains the following features:
# <ul>
#     <li>PassengerId</li>
#     <li>Survived (Survival: 0 = No; 1 = Yes)</li>
#     <li>Pclass (Passenger Class: 1 = 1st; 2 = 2nd; 3 = 3rd)</li>
#     <li>Name (Name of the passenger)</li>
#     <li>Sex (Sex of the passenger)</li>
#     <li>Age (Age of the passenger)</li>
#     <li>SibSp (Number of siblings / spourses aboard)</li>
#     <li>Parch (Number of parents / children aboard)</li>
#     <li>Ticket (Ticket number of the passenger)</li>
#     <li>Fare (Passenger fare)</li>
#     <li>Cabin (Cabin number of the passenger)</li>
#     <li>Embarked (Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton) )</li>
# </ul>

# %% [markdown]
# ## Steps:
# <ol>
#     <li>Part A: Data Pre-processing and Exploratory Analysis
#       (i.e. Preparing the training data)
#       <ul>
#       <li>1 Importing data and exploring the features.</li>
#       <li>2 Cleaning data: Handling missing values</li>
#       <li>3 Creating new features and dropping redundant features.</li>
#       <li>4 Transforming data.</li>
#       <li>5 Analysing data statistically.</li>
#       </ul>
#     </li>
#     <li>Part B: Data Prediction using Machine Learning
#       <ul>
#       <li>1. Training the model. (Assignment 2)</li>
#       <li>2. Preparing the testing data (Assignment 2)</li>
#           <ul>
#           <li>1 Importing data and exploring the features.</li>
#           <li>2 Cleaning data: Handling missing values</li>
#           <li>3 Creating new features and dropping redundant features.</li>
#           <li>4 Transforming data.</li>
#           </ul>
#       <li>3. Doing data prediction using the trained model.</li>
#       </ul>
#     </li>
# </ol>

# %% [markdown]
# ## Part A: Data Pre-processing and Exploratory Analysis

# %% [markdown]
# ### Step 1: Importing data and exploring the features
#
# #### Step 1.1
# Import the required libraries and read the data into a pandas DataFrame.
#
# - Read the csv file 'titanic-train.csv' using Pandas' read_csv function
# (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html">pandas.read_csv</a>)

# %%
import pandas as pd
import numpy as np
import seaborn
import matplotlib.pyplot as plt
import sklearn

train = pd.read_csv('titanic-train.csv')

# %% [markdown]
# #### Step 1.2
# Use head function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html">pandas.DataFrame.head</a>) of pandas library to preview the first 10 data.

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# #### Step 1.3
# Use tail function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.tail.html">pandas.DataFrame.tail</a>) of pandas library to preview the last 10 data.

# %%
train.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 881    male  33.0      0      0            349257   7.8958   NaN        S
# 882  female  22.0      0      0              7552  10.5167   NaN        S
# 883    male  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q

# %% [markdown]
# #### Step 1.4
# Display informtion on dataframe using info function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.info.html">pandas.DataFrame.info</a>) of pandas library.

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# #### Step 1.5
# Evaluate the data quality & perform missing values assessment using isnull function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.isnull.html">pandas.isnull</a>) and sum function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sum.html">pandas.DataFrame.sum</a>) of pandas library.

# %%
for i in range(12):
    print('Number of empty value in ' + train.columns[i] + ':')
    print(pd.isnull(train.iloc[:,i]).sum())
# Out:
# Number of empty value in PassengerId:
# 0
# Number of empty value in Survived:
# 0
# Number of empty value in Pclass:
# 0
# Number of empty value in Name:
# 0
# Number of empty value in Sex:
# 0
# Number of empty value in Age:
# 177
# Number of empty value in SibSp:
# 0
# Number of empty value in Parch:
# 0
# Number of empty value in Ticket:
# 0
# Number of empty value in Fare:
# 0
# Number of empty value in Cabin:
# 687
# Number of empty value in Embarked:
# 2

# %% [markdown]
# <span style="color:red">Observation</span>

# %% [markdown]
# - Attribute "Cabin" contains the most missing value with 687 values empty, reaching a missing rate of 77.10%.
#
# - Attribute "Age" contains the second most missing values with 177 missing, missing rate: 19.87%.
#
# - Attribute "Embarked" contains 2 missng values, only 0.22% missing.
#
# - The rest of the attributes contains no missing values, showing a good completeness.

# %% [markdown]
# #### Step 1.6
# Evaluate the distribution of categorical features (e.g., Name, Sex, Ticket, Cabin, and Embarked) using describe function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.describe.html">pandas.DataFrame.describe</a>) of the pandas library.

# %%
train[['Name','Sex','Ticket','Cabin','Embarked']].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %% [markdown]
# <span style="color:red">Observation</span>

# %% [markdown]
# - Values in "Name" are complete, with no missing values. All values in "Name" are unique due to a high accurary of the record, showing the dataset has minimum redundancy.
#
# - There are more male passengers than female passengers. Out of all passengers, 64.76% are male.
#
# - Out of all 891 records of "Ticket" number, only 681 of them are unique, implicating a low validity of these records. It can be inferred that some of the ticket numbers are not recorded accurately and correctly. The ticket number '347082' appeared most frequently (7 times) in the records.
#
# - Attribute "Cabin" has only 204 non-missing records. 147 out of the 204 cabin records are unique, which is expected because there are single rooms and non-single rooms. However, the validity of these records is doubtful as there are records of several cabin numbers under one passenger name. The record 'B96 B98' appeared 4 times in the data.
#
# - Attribute "Embarked" port has 3 unique values, corresponding to the 3 ports of embarkation: Cherbourg, Queenstown and Southampton. Among the non-empty records, 72.44% of the passengers are embarked from Southampton.

# %% [markdown]
# ### Step 2: Cleaning data: Handling missing values

# %% [markdown]
# #### Step 2.1
# Evaluate age distribution using hist function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.hist.html">pandas.DataFrame.hist</a>) of pandas library.

# %%
train['Age'].hist()
# Out:
# <Axes: >

# %% [markdown]
# <span style="color:red">observation</span>

# %% [markdown]
# - The histogram is right skewed, showing there are more younger passengers than older passengers.
#
# - The most common age group is around 20-30 years old, with approximately 175 passengers.
#
# - The age distribution has a wide range from 0-10 year old children to 80 year old seniors.
#
# - Number of passengers aged 30 above gradually decreases as age increases. Only a small number of passengers are aged 60-80. However, there is a significant number of children aged 0-10, with around 50 records in this range.
#
# In conclusion, the age distribution among passengers tend to be very young, with the largest age group at around 20-30 years old. The number of senior passengers are relatively very small.

# %% [markdown]
# #### Step 2.2
# Evaluate the 'Embarked' distribution using countplot function (<a href="https://seaborn.pydata.org/generated/seaborn.countplot.html">seaborn.countplot</a>) of seaborn library.

# %%
seaborn.countplot(train,x='Embarked')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# <span style="color:red">observation</span>

# %% [markdown]
# - Most of the passengers are embarked at Southampton port, with around 650 people embarked.
#
# - Cherbourg port has second largest group of embarking passengers, with around 170 passengers embarked. And Queenstown has the least passengers embarked, with only about 80 people  onboard.
#
# - Cherbourg and Queenstown has significantly smaller passengers than Southampton port, with Southampton has approximately 3 times larger passenger group embarked compared with that of C and Q port combined.
#
# In conclusion, most passengers are embarked at Southampton port, counting to nearly 3 quarter of the total passengers, while Cherbourg and Queenstown have significantly smaller passenger crowd onboard.

# %% [markdown]
# #### Step 2.3
# - For the feature with the second least missing values, if the data is not skewed, using mean to impute the missing values. Otherwise using median.
# - For the feature with the least missing values, impute the missing values with most the common value.

# %% [markdown]
# ##### Step 2.3.1
# Compute the median of the second least missing values using median function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.median.html">pandas.DataFrame.median</a>) of pandas library.
#
# Note: You have to skip all the missing values when computing the mean or median.

# %%
agemed=train['Age'].median(skipna=True)
print(agemed)
# Out:
# 28.0

# %% [markdown]
# <span style="color:red">observation</span>

# %% [markdown]
# The Age distribution is right skewed, use median (28) to impute the missing values.

# %% [markdown]
# ##### Step 2.3.2
# Use mean / median to impute the missing values of the feature with the second least missing values. fillna function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.fillna.html">pandas.DataFrame.fillna</a>) of pandas library can be used.

# %%
train['Age'] = train['Age'].fillna(agemed)
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  28.0      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# ##### Step 2.3.3
# Use the most common value of the feature with the least missing values to impute the missing values.

# %%
train['Embarked'] = train['Embarked'].fillna('S')

# %% [markdown]
# ### Step 3: Creating new features and dropping redundant features

# %% [markdown]
# #### Step 3.1
# Create a new feature called Family based on Parch and SibSp.
# - Define a new feature 'Family' and assign it with the sum of SibSp and Parch.

# %%
train['Family'] = train['SibSp'] + train['Parch']

# %% [markdown]
# #### Step 3.2
# Use head function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html">pandas.DataFrame.head</a>) of pandas library to preview the first 10 data.

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  28.0      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked  Family
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0
# 3      0            113803  53.1000  C123        S       1
# 4      0            373450   8.0500   NaN        S       0
# 5      0            330877   8.4583   NaN        Q       0
# 6      0             17463  51.8625   E46        S       0
# 7      1            349909  21.0750   NaN        S       4
# 8      2            347742  11.1333   NaN        S       2
# 9      0            237736  30.0708   NaN        C       1

# %% [markdown]
# #### Step 3.3
# - PassengerId, Name, Ticket, and Cabin may be dropped (using drop function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop.html">pandas.DataFrame.drop</a>) of the pandas library) as they contain high ratio of duplicates and there may not be a correlation to survivial.
# - In addition, SibSp and Parch can be dropped as the feature 'Family' has been defined.

# %%
train = train.drop(['PassengerId','Name','Ticket','Cabin','SibSp','Parch'], axis=1)

# %% [markdown]
# #### Step 3.4
# Use head function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html">pandas.DataFrame.head</a>) of pandas library to preview the first 10 data.

# %%
train.head(10)
# Out:
#    Survived  Pclass     Sex   Age     Fare Embarked  Family
# 0         0       3    male  22.0   7.2500        S       1
# 1         1       1  female  38.0  71.2833        C       1
# 2         1       3  female  26.0   7.9250        S       0
# 3         1       1  female  35.0  53.1000        S       1
# 4         0       3    male  35.0   8.0500        S       0
# 5         0       3    male  28.0   8.4583        Q       0
# 6         0       1    male  54.0  51.8625        S       0
# 7         0       3    male   2.0  21.0750        S       4
# 8         1       3  female  27.0  11.1333        S       2
# 9         1       2  female  14.0  30.0708        C       1

# %% [markdown]
# ### Step 4: Transforming data

# %% [markdown]
# ##### Step 4.1
# - Update the Family's values using where function (<a href="https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.where.html">numpy.where</a>) of numpy library as follows:
# <ul>
#     <li>0 if the Family's count is 0, which means single.</li>
#     <li>1 if the Family's count is greater than or equal to 1 AND less than or equal to 4, which means small family.</li>
#     <li>2 if the Family's count is greater than or equal to 5, means large family</li>
# </ul>

# %%
train['Family'] = np.where(train['Family'] == 0, 0, train['Family'])
train['Family'] = np.where((train['Family'] <= 4) & (train['Family'] >= 1), 1, train['Family'])
train['Family'] = np.where(train['Family'] >= 5, 2, train['Family'])
# train.head(10)

# %% [markdown]
# #### Step 4.2
# - Update the Sex's values to 1 if the original value is 'male'. Otherwise, update it to 0.
# - where function (<a href="https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.where.html">numpy.where</a>) of numpy library can be used.

# %%
train['Sex'] = np.where(train['Sex'] == 'male', 1, train['Sex'])
train['Sex'] = np.where(train['Sex'] == 'female', 0, train['Sex'])
# train.head(10)

# %% [markdown]
# #### Step 4.3
# - Update the Embarked values using where function (<a href="https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.where.html">numpy.where</a>) of numpy library as follows:
# <ul>
#     <li>0 if the Embarked value is C.</li>
#     <li>1 if the Embarked value is Q.</li>
#     <li>2 if teh Embarked value is S.</li>
# </ul>

# %%
train['Embarked'] = np.where(train['Embarked'] == 'C', 0, train['Embarked'])
train['Embarked'] = np.where(train['Embarked'] == 'Q', 1, train['Embarked'])
train['Embarked'] = np.where(train['Embarked'] == 'S', 2, train['Embarked'])
# train.head(10)

# %% [markdown]
# #### Step 4.4
# - Update the Fare values using where function (<a href="https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.where.html">numpy.where</a>) of numpy library as follows:
# <ul>
#     <li>0 if the Fare value is less than or equal to 7.91</li>
#     <li>1 if the Fare value is greater than 7.91 AND less than or equal to 14.454</li>
#     <li>2 if the Fare value is greater than 14.454 AND less than or equal to 31</li>
#     <li>3 if the Fare value is greater than 31</li>
# </ul>

# %%
train['Fare'] = np.where(train['Fare'] <= 7.91, 0, train['Fare'])
train['Fare'] = np.where((train['Fare'] > 7.91) & (train['Fare'] <= 14.454), 1, train['Fare'])
train['Fare'] = np.where((train['Fare'] > 14.454) & (train['Fare'] <= 31), 2, train['Fare'])
train['Fare'] = np.where(train['Fare'] > 31, 3, train['Fare'])
# train.head(10)

# %% [markdown]
# #### Step 4.5
# - Update the Age values using where function (<a href="https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.where.html">numpy.where</a>) of numpy library as follows:
# <ul>
#     <li>0 if the Age value is less than or equal to 16</li>
#     <li>1 if the Age value is greater than 16 AND less than or equal to 32</li>
#     <li>2 if the Age value is greater than 32 AND less than or equal to 48</li>
#     <li>3 if the Age value is greater than 48 AND less than or equal to 64</li>
#     <li>4 if the Age value is greater than 64</li>
# </ul>

# %%
train['Age'] = np.where(train['Age'] <= 16, 0, train['Age'])
train['Age'] = np.where((train['Age'] > 16) & (train['Age'] <= 32), 1, train['Age'])
train['Age'] = np.where((train['Age'] > 32) & (train['Age'] <= 48), 2, train['Age'])
train['Age'] = np.where((train['Age'] > 48) & (train['Age'] <= 64), 3, train['Age'])
train['Age'] = np.where(train['Age'] > 64, 4, train['Age'])
# train.head(10)

# %% [markdown]
# #### Step 4.6
# Change Embarked data to int type using astype function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html">pandas.DataFrame.astype</a>) of pandas library.

# %%
train['Embarked'] = train['Embarked'].astype('int32')
train['Embarked'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# #### Step 4.7
# Change Fare data from float to int type using astype function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html">pandas.DataFrame.astype</a>) of pandas library.

# %%
train['Fare'] = train['Fare'].astype('int32')
train['Fare'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# #### Step 4.8
# Change Age data from float to int type using astype function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html">pandas.DataFrame.astype</a>) of pandas library.

# %%
train['Age'] = train['Age'].astype('int32')
train['Age'].dtype
# Out:
# dtype('int32')

# %%
train['Sex'] = train['Sex'].astype('int32')
train['Sex'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# #### Step 4.9
# Use head function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html">pandas.DataFrame.head</a>) of pandas library to preview the first 20 data.

# %%
train.head(20)
# Out:
#     Survived  Pclass  Sex  Age  Fare  Embarked  Family
# 0          0       3    1    1     0         2       1
# 1          1       1    0    2     3         0       1
# 2          1       3    0    1     1         2       0
# 3          1       1    0    2     3         2       1
# 4          0       3    1    2     1         2       0
# 5          0       3    1    1     1         1       0
# 6          0       1    1    3     3         2       0
# 7          0       3    1    0     2         2       1
# 8          1       3    0    1     1         2       1
# 9          1       2    0    0     2         0       1
# 10         1       3    0    0     2         2       1
# 11         1       1    0    3     2         2       0
# 12         0       3    1    1     1         2       0
# 13         0       3    1    2     3         2       2
# 14         0       3    0    0     0         2       0
# 15         1       2    0    3     2         2       0
# 16         0       3    1    0     2         1       2
# 17         1       2    1    1     1         2       0
# 18         0       3    0    1     2         2       1
# 19         1       3    0    1     0         0       0

# %% [markdown]
# ### Step 5: Analysing data statistically and graphically

# %% [markdown]
# #### Step 5.1
# Use describe function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.describe.html">pands.DataFrame.describe</a>) of pandas library to generate descriptive statistics that summarize the central tendency, dispersion and shape of a dataset's distribution.

# %%
train.describe()
# Out:
#          Survived      Pclass         Sex         Age        Fare    Embarked  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.647587    1.290685    1.505051    1.536476
# std      0.486592    0.836071    0.477990    0.812620    1.118148    0.791503
# min      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000    1.000000    0.500000    1.000000
# 50%      0.000000    3.000000    1.000000    1.000000    2.000000    2.000000
# 75%      1.000000    3.000000    1.000000    2.000000    2.000000    2.000000
# max      1.000000    3.000000    1.000000    4.000000    3.000000    2.000000
#
#            Family
# count  891.000000
# mean     0.450056
# std      0.594476
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      2.000000

# %% [markdown]
# #### Step 5.2
# Explore survival rate using countplot function (<a href="https://seaborn.pydata.org/generated/seaborn.countplot.html">seaborn.countplot</a>) of seaborn library.

# %%
seaborn.countplot(train, x='Survived', stat='percent')
print(train.loc[train['Survived'] == 1, 'Survived'].count() / train['Survived'].count())
# Out:
# 0.3838383838383838

# %% [markdown]
# #### Step 5.3
# Perform other data analysis (e.g. on the features) to explore the factors constituting higher survival rate.

# %% [markdown]
# ##### Univariate analysis:

# %%
seaborn.countplot(train, x='Sex', hue='Survived')
#Survival rate among female:
print("Survival rate among female: ")
print(train.loc[(train['Sex'] == 0) & (train['Survived'] == 1), 'Sex'].count() / train.loc[train['Sex'] == 0, 'Sex'].count())
#Survival rate among male:
print("Survival rate among male: ")
print(train.loc[(train['Sex'] == 1) & (train['Survived'] == 1), 'Sex'].count() / train.loc[train['Sex'] == 1, 'Sex'].count())
# Out:
# Survival rate among female:
# 0.7420382165605095
# Survival rate among male:
# 0.18890814558058924

# %%
seaborn.countplot(train, x='Pclass', hue='Survived')
# Survival rate among each passenger class:
print("Survival rate among first class:")
print(train.loc[(train['Pclass'] == 1) & (train['Survived'] == 1), 'Survived'].count() / train.loc[train['Pclass'] == 1, 'Survived'].count())
print("Survival rate among second class:")
print(train.loc[(train['Pclass'] == 2) & (train['Survived'] == 1), 'Survived'].count() / train.loc[train['Pclass'] == 2, 'Survived'].count())
print("Survival rate among third class:")
print(train.loc[(train['Pclass'] == 3) & (train['Survived'] == 1), 'Survived'].count() / train.loc[train['Pclass'] == 3, 'Survived'].count())
# Out:
# Survival rate among first class:
# 0.6296296296296297
# Survival rate among second class:
# 0.47282608695652173
# Survival rate among third class:
# 0.24236252545824846

# %%
seaborn.countplot(train, x='Family', hue='Survived')
print("Survival rate among passengers with 0 family members:")
print(train.loc[(train['Family'] == 0) & (train['Survived'] == 1), 'Survived'].count() / train.loc[train['Family'] == 0, 'Survived'].count())
print("Survival rate among passengers with 1-4 family members:")
print(train.loc[(train['Family'] == 1) & (train['Survived'] == 1), 'Survived'].count() / train.loc[train['Family'] == 1, 'Survived'].count())
print("Survival rate among passengers with 5 and above family members:")
print(train.loc[(train['Family'] == 2) & (train['Survived'] == 1), 'Survived'].count() / train.loc[train['Family'] == 2, 'Survived'].count())
# Out:
# Survival rate among passengers with 0 family members:
# 0.30353817504655495
# Survival rate among passengers with 1-4 family members:
# 0.5602605863192183
# Survival rate among passengers with 5 and above family members:
# 0.14893617021276595

# %%
seaborn.countplot(train, x='Fare', hue='Survived')
print("Survival rate among passengers with range 0 fare:")
print(train.loc[(train['Fare'] == 0) & (train['Survived'] == 1), 'Survived'].count() / train.loc[train['Fare'] == 0, 'Survived'].count())
print("Survival rate among passengers with range 1 fare:")
print(train.loc[(train['Fare'] == 1) & (train['Survived'] == 1), 'Survived'].count() / train.loc[train['Fare'] == 1, 'Survived'].count())
print("Survival rate among passengers with range 2 fare:")
print(train.loc[(train['Fare'] == 2) & (train['Survived'] == 1), 'Survived'].count() / train.loc[train['Fare'] == 2, 'Survived'].count())
print("Survival rate among passengers with range 3 fare:")
print(train.loc[(train['Fare'] == 3) & (train['Survived'] == 1), 'Survived'].count() / train.loc[train['Fare'] == 3, 'Survived'].count())
# Out:
# Survival rate among passengers with range 0 fare:
# 0.19730941704035873
# Survival rate among passengers with range 1 fare:
# 0.3087557603686636
# Survival rate among passengers with range 2 fare:
# 0.44541484716157204
# Survival rate among passengers with range 3 fare:
# 0.581081081081081

# %%
seaborn.countplot(train, x='Age', hue='Survived')
print("Survival rate among passengers aged 0-15:")
print(train.loc[(train['Age'] == 0) & (train['Survived'] == 1), 'Survived'].count() / train.loc[train['Age'] == 0, 'Survived'].count())
print("Survival rate among passengers aged 16-31:")
print(train.loc[(train['Age'] == 1) & (train['Survived'] == 1), 'Survived'].count() / train.loc[train['Age'] == 1, 'Survived'].count())
print("Survival rate among passengers aged 32-47:")
print(train.loc[(train['Age'] == 2) & (train['Survived'] == 1), 'Survived'].count() / train.loc[train['Age'] == 2, 'Survived'].count())
print("Survival rate among passengers aged 48-64:")
print(train.loc[(train['Age'] == 3) & (train['Survived'] == 1), 'Survived'].count() / train.loc[train['Age'] == 3, 'Survived'].count())
print("Survival rate among passengers aged above 64:")
print(train.loc[(train['Age'] == 4) & (train['Survived'] == 1), 'Survived'].count() / train.loc[train['Age'] == 4, 'Survived'].count())
# Out:
# Survival rate among passengers aged 0-15:
# 0.55
# Survival rate among passengers aged 16-31:
# 0.3441682600382409
# Survival rate among passengers aged 32-47:
# 0.40425531914893614
# Survival rate among passengers aged 48-64:
# 0.43478260869565216
# Survival rate among passengers aged above 64:
# 0.09090909090909091

# %% [markdown]
# ##### Multivariate analysis:

# %%
# Among female passengers:
seaborn.countplot(train[train['Sex'] == 0], x='Pclass', hue='Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
# Among male passengers:
seaborn.countplot(train[train['Sex'] == 1], x='Pclass', hue='Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# ##### Further analysis: construct a decision tree using CART algorithm.

# %%
# %conda install python-graphviz

# %%
from sklearn import tree
import graphviz

x = train.drop(labels='Survived', axis=1) # x={Pclass Sex Age Fare Embarked Family}
y = train['Survived']
clf = tree.DecisionTreeClassifier(max_depth=3) # Tree depth:3
clf = clf.fit(x, y)

#Plot the decision tree:
dot_data = tree.export_graphviz(clf, out_file=None,
                                feature_names=['Pclass','Sex','Age','Fare','Embarked','Family'],
                                class_names=['Deseased','Survived'])
graph = graphviz.Source(dot_data)
graph.render('titanic')

# Or:
# plt.figure(figsize=(10,10), dpi=200)
# tree.plot_tree(clf)
# Out:
# 'titanic.pdf'

# %% [markdown]
# <span style="color:red">observations</span>

# %% [markdown]
# Overvall survival rate among passengers: 38.38%
#
# Univariate observations:
# - **Nearly 4 times higher chances of survival among female passengers than male passengers.** (Survival rate among female: 74.2%. Survival rate among male: 18.89%.)
# - **Classier cabin, higher chances of survival.** (Survival rate among first class, second class and third class are 62.96%, 47.28%, 24.24% respectively.)
# - **Passengers with 1-4 family members have the highest chances of survival, and those with 5 and above family members have the lowest.** (Survival rate among passengers with 0 family members: 30.35%, 1-4 family members: 56.03%, 5 and above family members: 14.89%.)
# - **Higher ticket fare, higher chances of survival.** (Survival rate among passengers with range 0, 1, 2, 3 fare: 19.73%, 30.88%, 44.54%, 58.11%.)
# - **0-15 year old passengers have the highest survival rate, followed by 48-64 and 32-47 year old passengers, and 16-31 year olds have the second lowest survival rate. 64 and above year olds survival rate sharply drop to a low at only 9.09%.** (Survival rate among passengers aged 0-15: 55%; aged 16-31: 34.42%; aged 32-47: 40.43%; aged 48-64: 43.48%; aged above 64: 9.09%.)
#
# Multivariate observations:
# - Consider Sex and Pclass.
#     - **Female passengers with First or Second class tickets have a significant survival chance boost from 74.2% to 94.7%, while females with Third class tickets have their survival chance drop to 50%.**
#     - **Male passengers with First class tickets have an increase of survival rate from 18.89% to 36.89%.**
# - From the Decision Tree using gini criterion.
#     - **The first significant factor affecting survival rate is Sex.**
#     - **Among both male and female passengers, the second important factor is Pclass as demontrated above.**
#     - Third important factor vary subjecting to Sex and Pclass.

# %% [markdown]
# ## Part B: Data Pre-processing and Exploratory Analysis

# %% [markdown]
# ### Step 0: Installation and Importing the libraries

# %% [markdown]
# #### Step 0.1
# We are going to use <strong>Keras</strong> which will be using <strong>Tensorflow</strong> as backend.

# %% [markdown]
# ### Step 1: Training the model
#
# #### Step 1.1

# %%
import tensorflow as tf
import keras
from keras import layers

# %%
# print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# %% [markdown]
# #### Step 1.2
# Prepare training data - feature set and label set
# - Build feature set X by extracting 'Pclass', 'Sex', 'Age', 'Fare', 'Embarked' and 'Family' from trainData
# - Build label set Y by extracting 'Survived' from trainData

# %%
x_train = train.drop(labels=['Survived'], axis=1)
y_train = train['Survived']
input_shape = (6,)

x_train.head(10)
# Out:
#    Pclass  Sex  Age  Fare  Embarked  Family
# 0       3    1    1     0         2       1
# 1       1    0    2     3         0       1
# 2       3    0    1     1         2       0
# 3       1    0    2     3         2       1
# 4       3    1    2     1         2       0
# 5       3    1    1     1         1       0
# 6       1    1    3     3         2       0
# 7       3    1    0     2         2       1
# 8       3    0    1     1         2       1
# 9       2    0    0     2         0       1

# %% [markdown]
# #### Step 1.3
# - Build a neural network to learn from the given training set - trainData.
# (Reference: <a href="https://keras.io/guides/sequential_model/">Here</a>)
# <ol>
#   <li>Initalizing a neural network using Sequential() function and name the returned object NN.</li>
#   <li>Adding the input layer and the hidden layer using add function of NN and Dense function.<br/>
#       Parameters of Dense function:
#       <ul>
#           <li>Set output_dim to 9: output_dim is the number of nodes we want to add to this layer.</li>
#           <li>kernel_initializer to 'random_uniform': the initialization of weights for stochastic gradient decent.
#           </li>
#           <li>activation to 'sigmoid': activation is the activation function of the node.</li>
#           <li>input_dim to 6: input_dim refers to the number of inputs, which is only needed for the first layer.</li>
#       </ul>
#   </li>
#   <li>Adding the output layer using add function of NN and Dense function.<br/>
#       Parameters of Dense function:
#       <ul>
#           <li>Set output_dim to 1: output_dim is the number of nodes we want to add to this layer.</li>
#           <li>kernel_initializer to 'random_uniform': the initialization of weights for stochastic gradient decent.</li>
#           <li>activation to 'sigmoid': activation is the activation function of the node.</li>
#       </ul>
#   </li>
#   <li>Prints a summary representation of our model by calling summary function of NN.</li>
# </ol>
#
# more information about the weight initializer: <a href="here">https://keras.io/api/layers/initializers/</a>

# %%
NN = keras.Sequential(name='nn')
NN.add(keras.Input(shape=input_shape))
NN.add(layers.Dense(9, activation='sigmoid', kernel_initializer='random_uniform'))
NN.add(layers.Dense(1, activation='sigmoid', kernel_initializer='random_uniform'))

NN.summary()
# Out:
# Model: "nn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 9)              │            63 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            10 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 73 (292.00 B)
#  Trainable params: 73 (292.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Step 1.4
# - Compile the neural network and start training
# <ol>
#   <li>Call compile function of NN to compile the neural network<br/>
#       Parameters of compile function:
#       <ul>
#           <li>loss to 'binary_crossentropy': loss is a stochastic gradient decent depends on loss. Since the dependent variable in our case is binary, we will have to use logarithmic loss function called 'binary_crossentropy'.</li>
#           <li>optimizer to 'Adam': optimizer is the algorithm that we want to use to find optimal set of weights. For details about 'Adam', please visit <a href="https://arxiv.org/abs/1412.6980v8">here</a>.
#           </li>
#           <li>metrics to ['accuracy']: metrics is the metric(s) that we want to use to improve the performance of our neural network. In our case, accuracy is the metrics.</li>
#       </ul>
#   </li>
#   <li>Call fit function of NN to train the model on training data<br/>
#       Parameters of fit function:
#       <ul>
#           <li>Set x to X: x is the numpy array of training data.</li>
#           <li>Set y to Y: y is the numpy array of label data.</li>
#           <li>Set batch_size to 32: batch_size is the number of samples per gradient update.</li>
#           <li>Set epochs to 10000: epochs is the number of epochs to train the model.</li>
#       </ul>
#   </li>
# </ol>

# %%
batch_size = 32
epochs = 10000
NN.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
NN.fit(x_train, y_train, batch_size=batch_size, epochs=epochs)
# Out:
# Epoch 1/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - accuracy: 0.4566 - loss: 0.6953
# Epoch 2/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 259us/step - accuracy: 0.6206 - loss: 0.6806
# Epoch 3/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - accuracy: 0.6112 - loss: 0.6733
# Epoch 4/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 266us/step - accuracy: 0.6481 - loss: 0.6567
# Epoch 5/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 277us/step - accuracy: 0.6203 - loss: 0.6602
# Epoch 6/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 283us/step - accuracy: 0.6369 - loss: 0.6503
# Epoch 7/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 263us/step - accuracy: 0.6346 - loss: 0.6480
# Epoch 8/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 247us/step - accuracy: 0.6142 - loss: 0.6553
# Epoch 9/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 262us/step - accuracy: 0.6007 - loss: 0.6609
# Epoch 10/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 256us/step - accuracy: 0.6431 - loss: 0.6355
# Epoch 11/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 252us/step - accuracy: 0.6192 - loss: 0.6442
# Epoch 12/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 266us/step - accuracy: 0.6216 - loss: 0.6402
# Epoch 13/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 262us/step - accuracy: 0.6078 - loss: 0.6461
# Epoch 14/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 258us/step - accuracy: 0.6474 - loss: 0.6174
# Epoch 15/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 279us/step - accuracy: 0
10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8314 - loss: 0.3857
# Epoch 9982/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step - accuracy: 0.8342 - loss: 0.3837
# Epoch 9983/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - accuracy: 0.8424 - loss: 0.3632
# Epoch 9984/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8512 - loss: 0.3641
# Epoch 9985/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - accuracy: 0.8488 - loss: 0.3550
# Epoch 9986/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 344us/step - accuracy: 0.8326 - loss: 0.3661
# Epoch 9987/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8431 - loss: 0.3759
# Epoch 9988/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - accuracy: 0.8473 - loss: 0.3642
# Epoch 9989/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8345 - loss: 0.3751
# Epoch 9990/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step - accuracy: 0.8517 - loss: 0.3484
# Epoch 9991/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8560 - loss: 0.3491
# Epoch 9992/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step - accuracy: 0.8458 - loss: 0.3527
# Epoch 9993/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8575 - loss: 0.3558
# Epoch 9994/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - accuracy: 0.8481 - loss: 0.3627
# Epoch 9995/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - accuracy: 0.8504 - loss: 0.3444
# Epoch 9996/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - accuracy: 0.8583 - loss: 0.3396
# Epoch 9997/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - accuracy: 0.8157 - loss: 0.3954
# Epoch 9998/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - accuracy: 0.8298 - loss: 0.3725
# Epoch 9999/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step - accuracy: 0.8521 - loss: 0.3452
# Epoch 10000/10000
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step - accuracy: 0.8390 - loss: 0.3642

# %% [markdown]
# ### Step 2: Preparing the testing data
#
# Steps for preprocessing the testing data:
# <ol>
# <li>Importing data and exploring the features.</li>
# <li>Cleaning data: Handling missing values</li>
# <li>Creating new features and dropping redundant features.</li>
# <li>Transforming data.</li>
# </ol>

# %% [markdown]
# #### Step 2.1 Importing data and exploring the features
# ##### Step 2.1.1
# Read the csv file 'titanic-test.csv' using Pandas' read_csv function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html">pandas.read_csv</a>)

# %%
test = pd.read_csv('titanic-test.csv')

# %% [markdown]
# ##### Step 2.1.2
# Use head function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html">pandas.DataFrame.head</a>) of pandas library to preview the first 10 data.

# %%
test.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  34.5      0      0     330911   7.8292   NaN        Q
# 1  47.0      1      0     363272   7.0000   NaN        S
# 2  62.0      0      0     240276   9.6875   NaN        Q
# 3  27.0      0      0     315154   8.6625   NaN        S
# 4  22.0      1      1    3101298  12.2875   NaN        S
# 5  14.0      0      0       7538   9.2250   NaN        S
# 6  30.0      0      0     330972   7.6292   NaN        Q
# 7  26.0      1      1     248738  29.0000   NaN        S
# 8  18.0      0      0       2657   7.2292   NaN        C
# 9  21.0      2      0  A/4 48871  24.1500   NaN        S

# %% [markdown]
# ##### Step 2.1.3
# Use tail function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.tail.html">pandas.DataFrame.tail</a>) of pandas library to preview the last 10 data.

# %%
test.tail(10)
# Out:
#      PassengerId  Pclass                                             Name  \
# 408         1300       3                  Riordan, Miss. Johanna Hannah""
# 409         1301       3                        Peacock, Miss. Treasteall
# 410         1302       3                           Naughton, Miss. Hannah
# 411         1303       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412         1304       3                   Henriksson, Miss. Jenny Lovisa
# 413         1305       3                               Spector, Mr. Woolf
# 414         1306       1                     Oliva y Ocana, Dona. Fermina
# 415         1307       3                     Saether, Mr. Simon Sivertsen
# 416         1308       3                              Ware, Mr. Frederick
# 417         1309       3                         Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 408  female   NaN      0      0              334915    7.7208   NaN        Q
# 409  female   3.0      1      1  SOTON/O.Q. 3101315   13.7750   NaN        S
# 410  female   NaN      0      0              365237    7.7500   NaN        Q
# 411  female  37.0      1      0               19928   90.0000   C78        Q
# 412  female  28.0      0      0              347086    7.7750   NaN        S
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C

# %% [markdown]
# ##### Step 2.1.4
# Display informtion on dataframe using info function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.info.html">pandas.DataFrame.info</a>) of pandas library.

# %%
test.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %% [markdown]
# ##### Step 2.1.5
# Evaluate the data quality & perform missing values assessment using isnull function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.isnull.html">pandas.isnull</a>) and sum function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sum.html">pandas.DataFrame.sum</a>) of pandas library.

# %%
for i in range(11):
    print('Number of empty value in ' + test.columns[i] + ':')
    print(pd.isnull(test.iloc[:,i]).sum())
# Out:
# Number of empty value in PassengerId:
# 0
# Number of empty value in Pclass:
# 0
# Number of empty value in Name:
# 0
# Number of empty value in Sex:
# 0
# Number of empty value in Age:
# 86
# Number of empty value in SibSp:
# 0
# Number of empty value in Parch:
# 0
# Number of empty value in Ticket:
# 0
# Number of empty value in Fare:
# 1
# Number of empty value in Cabin:
# 327
# Number of empty value in Embarked:
# 0

# %% [markdown]
# ##### Step 2.1.6
# Evaluate the distribution of categorical features (e.g., Name, Sex, Ticket, Cabin, and Embarked) using describe function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.describe.html">pandas.DataFrame.describe</a>) of the pandas library.

# %%
test[['Name','Sex','Ticket','Cabin','Embarked']].describe()
# Out:
#                     Name   Sex    Ticket            Cabin Embarked
# count                418   418       418               91      418
# unique               418     2       363               76        3
# top     Kelly, Mr. James  male  PC 17608  B57 B59 B63 B66        S
# freq                   1   266         5                3      270

# %% [markdown]
# #### Step 2.2 Cleaning Data: Handling missing values
# ##### Step 2.2.1
# For the feature with the second least number of missing values, evaluate its distribution using hist function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.hist.html">pandas.DataFrame.hist</a>) of pandas library.

# %%
test['Age'].hist()
# Out:
# <Axes: >

# %% [markdown]
# #### Step 2.2.2
# - For the feature with the second least missing values, if the data is not skewed, using mean to impute the missing values. Otherwise using median.
#
# ##### Step 2.2.2.1
# Compute the mean OR median of the second least missing values using mean (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.mean.html">pandas.DataFrame.mean</a>) / median function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.median.html">pandas.DataFrame.median</a>) of pandas library.
#
# Note: You have to skip all the missing values when computing the mean or median.

# %%
agemed_test=test['Age'].median(skipna=True)
print(agemed_test)
# Out:
# 27.0

# %% [markdown]
# ##### Step 2.2.2.2
# Use the mean value of the feature with the least missing values to impute the missing values.

# %%
test['Fare'] = test['Fare'].fillna(test['Fare'].mean(skipna=True))

# %% [markdown]
# ##### Step 2.2.2.3
# Use mean / median to impute the missing values of the feature with the second least missing values.

# %%
test['Age'] = test['Age'].fillna(agemed_test)

# %% [markdown]
# #### Step 2.3: Creating new features and dropping redundant features
# ##### Step 2.3.1
# Create a new feature called Family based on Parch and SibSp.
# - Define a new feature 'Family' and assign it with the sum of SibSp and Parch.

# %%
test['Family'] = test['SibSp'] + test['Parch']

# %% [markdown]
# ##### Step 2.3.2
# Use head function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html">pandas.DataFrame.head</a>) of pandas library to preview the first 10 data.

# %%
test.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked  Family
# 0  34.5      0      0     330911   7.8292   NaN        Q       0
# 1  47.0      1      0     363272   7.0000   NaN        S       1
# 2  62.0      0      0     240276   9.6875   NaN        Q       0
# 3  27.0      0      0     315154   8.6625   NaN        S       0
# 4  22.0      1      1    3101298  12.2875   NaN        S       2
# 5  14.0      0      0       7538   9.2250   NaN        S       0
# 6  30.0      0      0     330972   7.6292   NaN        Q       0
# 7  26.0      1      1     248738  29.0000   NaN        S       2
# 8  18.0      0      0       2657   7.2292   NaN        C       0
# 9  21.0      2      0  A/4 48871  24.1500   NaN        S       2

# %% [markdown]
# ##### Step 2.3.3
# - PassengerId, Name, Ticket, and Cabin may be dropped (using drop function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop.html">pandas.DataFrame.drop</a>) of the pandas library) as they contain high ratio of duplicates and there may not be a correlation to survivial.
# - In addition, SibSp and Parch can be dropped as the feature 'Family' has been defined.

# %%
test = test.drop(labels=['PassengerId','Name','Ticket','Cabin','SibSp','Parch'], axis=1)

# %% [markdown]
# ##### Step 2.3.4
# Use head function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html">pandas.DataFrame.head</a>) of pandas library to preview the first 10 data.

# %%
test.head(10)
# Out:
#    Pclass     Sex   Age     Fare Embarked  Family
# 0       3    male  34.5   7.8292        Q       0
# 1       3  female  47.0   7.0000        S       1
# 2       2    male  62.0   9.6875        Q       0
# 3       3    male  27.0   8.6625        S       0
# 4       3  female  22.0  12.2875        S       2
# 5       3    male  14.0   9.2250        S       0
# 6       3  female  30.0   7.6292        Q       0
# 7       2    male  26.0  29.0000        S       2
# 8       3  female  18.0   7.2292        C       0
# 9       3    male  21.0  24.1500        S       2

# %% [markdown]
# #### Step 2.4: Transforming data
# ##### Step 2.4.1
# - Update the Family's values using where function (<a href="https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.where.html">numpy.where</a>) of numpy library as follows:
# <ul>
#     <li>0 if the Family's count is 0, which means single.</li>
#     <li>1 if the Family's count is greater than or equal to 1 AND less than or equal to 4, which means small family.</li>
#     <li>2 if the Family's count is greater than or equal to 5, means large family</li>
# </ul>

# %%
test['Family'] = np.where(test['Family'] == 0, 0, test['Family'])
test['Family'] = np.where((test['Family'] <= 4) & (test['Family'] >= 1), 1, test['Family'])
test['Family'] = np.where(test['Family'] >= 5, 2, test['Family'])

# %% [markdown]
# ##### Step 2.4.2
# - Update the Sex's values to 1 if the original value is 'male'. Otherwise, update it to 0.
# - where function (<a href="https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.where.html">numpy.where</a>) of numpy library can be used.

# %%
test['Sex'] = np.where(test['Sex'] == 'male', 1, test['Sex'])
test['Sex'] = np.where(test['Sex'] == 'female', 0, test['Sex'])

# %% [markdown]
# ##### Step 2.4.3
# - Update the Embarked values using where function (<a href="https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.where.html">numpy.where</a>) of numpy library as follows:
# <ul>
#     <li>0 if the Embarked value is C.</li>
#     <li>1 if the Embarked value is Q.</li>
#     <li>2 if teh Embarked value is S.</li>
# </ul>

# %%
test['Embarked'] = np.where(test['Embarked'] == 'C', 0, test['Embarked'])
test['Embarked'] = np.where(test['Embarked'] == 'Q', 1, test['Embarked'])
test['Embarked'] = np.where(test['Embarked'] == 'S', 2, test['Embarked'])

# %% [markdown]
# ##### Step 2.4.4
# - Update the Fare values using where function (<a href="https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.where.html">numpy.where</a>) of numpy library as follows:
# <ul>
#     <li>0 if the Fare value is less than or equal to 7.91</li>
#     <li>1 if the Fare value is greater than 7.91 AND less than or equal to 14.454</li>
#     <li>2 if the Fare value is greater than 14.454 AND less than or equal to 31</li>
#     <li>3 if the Fare value is greater than 31</li>
# </ul>

# %%
test['Fare'] = np.where(test['Fare'] <= 7.91, 0, test['Fare'])
test['Fare'] = np.where((test['Fare'] > 7.91) & (test['Fare'] <= 14.454), 1, test['Fare'])
test['Fare'] = np.where((test['Fare'] > 14.454) & (test['Fare'] <= 31), 2, test['Fare'])
test['Fare'] = np.where(test['Fare'] > 31, 3, test['Fare'])

# %% [markdown]
# ##### Step 2.4.5
# - Update the Age values using where function (<a href="https://docs.scipy.org/doc/numpy-1.14.0/reference/generated/numpy.where.html">numpy.where</a>) of numpy library as follows:
# <ul>
#     <li>0 if the Age value is less than or equal to 16</li>
#     <li>1 if the Age value is greater than 16 AND less than or equal to 32</li>
#     <li>2 if the Age value is greater than 32 AND less than or equal to 48</li>
#     <li>3 if the Age value is greater than 48 AND less than or equal to 64</li>
#     <li>4 if the Age value is greater than 64</li>
# </ul>

# %%
test['Age'] = np.where(test['Age'] <= 16, 0, test['Age'])
test['Age'] = np.where((test['Age'] > 16) & (test['Age'] <= 32), 1, test['Age'])
test['Age'] = np.where((test['Age'] > 32) & (test['Age'] <= 48), 2, test['Age'])
test['Age'] = np.where((test['Age'] > 48) & (test['Age'] <= 64), 3, test['Age'])
test['Age'] = np.where(test['Age'] > 64, 4, test['Age'])

# %% [markdown]
# ##### Step 2.4.6
# Change Embarked data to int type using astype function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html">pandas.DataFrame.astype</a>) of pandas library.

# %%
test['Embarked'] = test['Embarked'].astype('int')

# %% [markdown]
# ##### Step 2.4.7
# Change Fare data from float to int type using astype function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html">pandas.DataFrame.astype</a>) of pandas library.

# %%
test['Fare'] = test['Fare'].astype('int')

# %% [markdown]
# ##### Step 2.4.8
# Change Age data from float to int type using astype function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html">pandas.DataFrame.astype</a>) of pandas library.

# %%
test['Age'] = test['Age'].astype('int')

# %%
test['Sex'] = test['Sex'].astype('int')

# %% [markdown]
# ##### Step 2.4.9
# Use head function (<a href="https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html">pandas.DataFrame.head</a>) of pandas library to preview the first 20 data.

# %%
test.head(20)
# Out:
#     Pclass  Sex  Age  Fare  Embarked  Family
# 0        3    1    2     0         1       0
# 1        3    0    2     0         2       1
# 2        2    1    3     1         1       0
# 3        3    1    1     1         2       0
# 4        3    0    1     1         2       1
# 5        3    1    0     1         2       0
# 6        3    0    1     0         1       0
# 7        2    1    1     2         2       1
# 8        3    0    1     0         0       0
# 9        3    1    1     2         2       1
# 10       3    1    1     0         2       0
# 11       1    1    2     2         2       0
# 12       1    0    1     3         2       1
# 13       2    1    3     2         2       1
# 14       1    0    2     3         2       1
# 15       2    0    1     2         0       1
# 16       2    1    2     1         1       0
# 17       3    1    1     0         0       0
# 18       3    0    1     1         2       1
# 19       3    0    2     0         0       0

# %% [markdown]
# ### Step 3: Use the NN model to predict the results
#
# Predicting whether or not the passengers survived the sinking of the Titanic.
# <ol>
#     <li>Use predict function of NN to predict testData. The predictions will be in the range between 0 and 1.</li>
#     <li>If the predicted value is greater than 0.5, set it to 1, otherwise, set it to 0.
#     </li>
#     <li>Save the classification results to a CSV file: prediction-ann.csv (for example, you may use the pandas.DataFrame.to_csv function).</li>
# </ol>

# %%
test.describe()
# Out:
#            Pclass         Sex         Age        Fare    Embarked      Family
# count  418.000000  418.000000  418.000000  418.000000  418.000000  418.000000
# mean     2.265550    0.636364    1.303828    1.492823    1.401914    0.425837
# std      0.841838    0.481622    0.762449    1.148953    0.854496    0.554469
# min      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000    0.000000    1.000000    0.000000    1.000000    0.000000
# 50%      3.000000    1.000000    1.000000    2.000000    2.000000    0.000000
# 75%      3.000000    1.000000    2.000000    3.000000    2.000000    1.000000
# max      3.000000    1.000000    4.000000    3.000000    2.000000    2.000000

# %%
result = NN.predict(test)
result = np.where(result <= 0.5, 0, result)
result = np.where(result > 0.5, 1, result)

result = pd.DataFrame(result)
result.to_csv('predict.csv')
# result.to_csv()
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ### Submission
# Submit your jupyter notebook (.ipynb) and the classification results (prediction-ann.csv).
